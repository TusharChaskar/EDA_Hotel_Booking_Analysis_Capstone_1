# %% [markdown]
# ## **Project Name :- Hotel Booking Analysis**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Project Summary :-**
#
# ### **I have divided my work flow into 3 steps which are as follow :**
# ### **1. Data Collection And Understanding :-**
# #### The Understanding of given data is very important for doing analysis On it. I have Data of Hotel Bookings which has total 1,19,390 rows and 32 columns in it, this 32 columns are as follows:-
# ####1. Hotel.
# ####2. is_canceled.
# ####3. lead_time.
# ####4. arrival_date_year.
# ####5. arrival_date_month.
# ####6. arrival_date_week_number.
# ####7. arrival_date_day_of_month.
# ####8. stays_in_weekend_nights.
# ####9. stays_in_week_nights.
# ####10. adults.
# ####11. children.
# ####12. babies.
# ####13. meal.
# ####14. country.
# ####15. market_segment.
# ####16. distribution_channel.
# ####17. is_repeated_guest.
# ####18. Previous_cancellations.
# ####19. previous_booking_not_cancelled.
# ####20. reserved_room_type.
# ####21. assigned_room_type.
# ####22. booking_changes.
# ####23. deposit_type.
# ####24. agent.
# ####25. company.
# ####26. days_in_waiting_list.
# ####27. customer_type.
# ####28. ADR.
# ####29. required_car_parking_spaces.
# ####30. total_of_special_requests.
# ####31. reservation_status.
# ####32. reservation_status_data.
# ### **2. Data Cleaning And Data Manipulation:-**
# #### 1. There is four columns which has missing values, i.e company, agent, country and children therefore i have replaced that Null Values with 0 in company, agent, children column And as Other in Country Column.
# #### 2. There is duplicate values are present in our data so i have dropped that rows.
# #### 3. I have created two new columns i.e Total_No_of_Person And ‘Total_Stay’ and then I have dropped the rows where total no of person is zero
# ### **3. Exploratory Data Analysis i.e EDA:-**
# ### **Exploratory Data Analysis is divided into following 3 analysis :**
# ####1. Univariate Analysis :- Univariate analysis is basically the simplest form to analyze data. Uni means one and this means that the data has only one kind of variable. The analysis will take data, summarise it, and then find some pattern in the data..
# ####2. Bivariate Analysis :- Bivariate analysis refers to the analysis of two variables to determine relationships between them. Bivariate analyses are often reported in quality of life research.
# ####3. Multivariate Analysis :- The statistical study of data where multiple measurements are made on each experimental unit and where the relationships among multivariate measurements and their Structure are important.

# %% [markdown]
# ## **Problem Statement :-**
# ### <b> Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to received is proportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# ### <b>This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. </b>
#
# ### <b> The major goal of this project is to study and analyse data to identify significant elements that influence bookings and provide management with information so they can run various campaigns to increase revenue and performance. </b>

# %% [markdown]
# ## **GitHub Link :-**

# %% [markdown]
# ## **Importing Needful Liabraries**

# %%
# Importing Liabraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# set max columns to be display in dataframe as 36
pd.set_option("display.max_columns",36)
plt.style.use("seaborn")

# Setting fontsizes,fontweight,label weight for lebels,titles.
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titleweight"] = "bold"
plt.rcParams["axes.titlesize"] = 25
plt.rcParams['xtick.labelsize']=15
plt.rcParams['ytick.labelsize']=15
plt.rcParams["axes.labelsize"] = 20
plt.rcParams["legend.fontsize"] = 15
plt.rcParams["legend.title_fontsize"] = 15

# %% [markdown]
# ## **Mounting Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **CSV Location**

# %%
location = '/content/drive/MyDrive/Data Science Program/5.Capstone Projects/1.Exploratory Data Analysis Capstone Project/Hotel Bookings.csv'

# %% [markdown]
# ## **Read File**

# %%
df = pd.read_csv(location)

# %% [markdown]
# ## **Data Exploration**

# %%
# checking the shape of dataframe
print(f"The Dataframe has {df.shape[0]} Rows And {df.shape[1]} Columns")
# Out:
# The Dataframe has 119390 Rows And 32 Columns

# %%
# Checking First 5 Rows
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
# Checking Last 5 Rows
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
# Looking the description of dataframe like Min, Max, 25 percentile, 50 percentile, 75 percentile
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# Looking all data is not null or there is some null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# ### **Data Description**
#
# 1. **Hotel** : Showing Type of Hotel i.e City Hotel or Resort Hotel.
# 2. **is_canceled** : Indicating the value for canceled(1) And Not Canceled(0).
# 3. **lead_time** : The number of days that passed between the booking date And the arrival date after it was entered into the PMS.
# 4. **arrival_date_year** : Showing Year of Arrival Date.
# 5. **arrival_date_month** : Showing Month of Arrival Date.
# 6. **arrival_date_week_number** : Showing the Week number of year for arrival date.
# 7. **arrival_date_day_of_month** : Showing the Day of arrival date.
# 8. **stays_in_weekend_nights** : Showing the Number of Saturday or Sunday nights the visitor spent or reserved to spend at the hotel.
# 9. **stays_in_week_nights** : Showing the Number of weeknights (Monday to Friday) the visitor stayed or made a reservation at the hotel.
# 10. **adults** : Showing the Number of Adults.
# 11. **children** : Showing the Number of Childrens.
# 12. **babies** : Showing the Number of babies.
# 13. **meal** : Showing the booked meal type. Category presentations are made in typical hospitality meal packages.
# 14. **country** : Showing the Country of origin.
# 15. **market_segment** : Showing Naming a market segment. The terms "TA" and "TO" stand for "Travel Agents" and "Tour Operators" respectively in categories.
# 16. **distribution_channel** : Showing Distribution method for reservations. Travel agents are referred to as "TA" and tour operators as "TO".
# 17. **is_repeated_guest** : Showing Value indicating if the booking name was from a repeated guest(1) or not(0).
# 18. **previous_cancellations** : Showing the Number of past reservations that the consumer cancelled before the current reservation.
# 19. **previous_bookings_not_canceled** : Showing the Number of earlier reservations that the customer did not cancel before the current reservation.
# 20. **reserved_room_type** : Showing the reserved room type code. To preserve anonymity, code is used in place of designation.
# 21. **assigned_room_type** : Showing the Code for the type of room assigned to the booking.
# 22. **booking_changes** : Showing the number of modifications/changes made to the reservation from the time it was entered on the PMS to check-in or cancellation.
# 23. **deposit_type** :Indicate whether the customer paid a deposit to secure the reservation.
# 24. **agent** : Showing the ID of the travel agency that made the booking.
# 25. **company** : Showing the ID of the company or other entity that made the reservation or is in charge of making the payment.
# 26. **days_in_waiting_list** : Showing How long the reservation was on wait before the consumer received confirmation.
# 27. **customer_type** : Showing the type of booking, assuming one of four categories.
# 28. **adr** : ADR is determined by dividing the total of all hotel transactions by the total number of nights spent there.
# 29. **required_car_parking_spaces** : Showing the Number of parking spaces the consumer needs.
# 30. **total_of_special_requests** :Showing the Number of special requests made by the customer (e.g. twin bed or high floor).
# 31. **reservation_status** : Reservation status, assuming one out of three categories,
# * Canceled – booking was canceled by the customer.
# * Check-Out – customer has checked in but already departed.
# * No-Show – customer did not check-in and did inform the hotel of the reason why?.
# 32. **reservation_status_date** : The most recent date the status was set. To determine when the reservation was cancelled or the customer checked out of the hotel, use this variable in conjunction with the Reservation Status.

# %%
# Creating Copy of Dataset.
df1 = df.copy()

# %%
# List of Column names.
print(list(df1.columns))
# Out:
# ['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date']

# %%
    # Converting Datatype to Datetime.
df1['reservation_status_date'] = pd.to_datetime(df1['reservation_status_date'], format = '%Y-%m-%d')

# %% [markdown]
# ## **Data Cleaning**

# %%
# checking for the duplicate rows. # True Means Duplicated Rows.
x = df1.duplicated().value_counts()
x
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
# drop the duplicate rows.
df1 = df1.drop_duplicates()

# %%
# Check Shape of DataFrame.
df1.shape
# Out:
# (87396, 32)

# %%
# Checking the null values.
df1.isna().sum().sort_values(ascending=False)[:4].reset_index().rename(columns={'index':'Columns',0:'Null values'})
# Out:
#     Columns  Null values
# 0   company        82137
# 1     agent        12193
# 2   country          452
# 3  children            4

# %% [markdown]
# #### So We Have Null Values in Company Column, Agent Column, Country Column And Children Column.
# #### 1. I will fill missing values as 0 in column company, agent and children.
# #### 2. I will fill missing values as 'Others' in country column.

# %%
# Filling/replacing null values with 0.
null_columns = ['company','agent','children']
for col in null_columns:
  df1[col].fillna(0,inplace=True)

# Filling/replacing null values with Others.
df1['country'].fillna('Others',inplace=True)

# %%
# Checking null values again.
df1.isna().sum().sort_values(ascending=False)[:4].reset_index().rename(columns={'index':'Columns',0:'Null values'})
# Out:
#                      Columns  Null values
# 0                      hotel            0
# 1                is_canceled            0
# 2         reservation_status            0
# 3  total_of_special_requests            0

# %%
# droppping all those rows in which addtion of of adlults ,children and babies is 0.
df1['Total_No_of_Persons'] = df1['adults']+df1['children']+df1['babies']
df1.drop(df1[df1['Total_No_of_Persons']==0].index,inplace=True)

# %%
# Checking the unique values in categorical columns.
category_col = list(set(df1.drop(columns=['reservation_status_date','country','arrival_date_month'])) - set(df1.describe()))
for col in category_col:
  print(f'The Unique Value in {col} is {(df1[col].unique())}')
# Out:
# The Unique Value in assigned_room_type is ['C' 'A' 'D' 'E' 'G' 'F' 'I' 'B' 'H' 'L' 'K']
# The Unique Value in hotel is ['Resort Hotel' 'City Hotel']
# The Unique Value in market_segment is ['Direct' 'Corporate' 'Online TA' 'Offline TA/TO' 'Complementary' 'Groups'
#  'Undefined' 'Aviation']
# The Unique Value in customer_type is ['Transient' 'Contract' 'Transient-Party' 'Group']
# The Unique Value in reservation_status is ['Check-Out' 'Canceled' 'No-Show']
# The Unique Value in reserved_room_type is ['C' 'A' 'D' 'E' 'G' 'F' 'H' 'L' 'B']
# The Unique Value in meal is ['BB' 'FB' 'HB' 'SC' 'Undefined']
# The Unique Value in distribution_channel is ['Direct' 'Corporate' 'TA/TO' 'Undefined' 'GDS']
# The Unique Value in deposit_type is ['No Deposit' 'Refundable' 'Non Refund']

# %%
# lets add total stay column.
df1['Total_Stay'] = df1['stays_in_week_nights'] + df1['stays_in_weekend_nights']

# %%
# Checking the final rows and columns
df1.shape
# Out:
# (87230, 34)

# %% [markdown]
# ## **Exploratory Data Analysis (EDA)**

# %% [markdown]
# ## **Univariate Analysis**

# %% [markdown]
# ## **1. Which kind of hotel do visitors prefer the most?**

# %%
# Checking No of Bookings Made.
bookings = df1['hotel'].value_counts().reset_index().rename(columns = {'index':'Hotel_type','hotel':'No_of_bookings'})
bookings
# Out:
#      Hotel_type  No_of_bookings
# 0    City Hotel           53274
# 1  Resort Hotel           33956

# %%
# Visualizsing the No of Bookings by pie chart.
df1['hotel'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%.2f%%',figsize=(10,8),fontsize=20)  
plt.title('Pie Chart for Most Preffered  Hotel')
# Out:
# Text(0.5, 1.0, 'Pie Chart for Most Preffered  Hotel')

# %% [markdown]
# #### **Observation :**
# City Hotel is most prefered by the visitor because City Hotel has maximum

# %% [markdown]
# ## **2. Which Agent booked the most bookings?**

# %%
# Checking No of Bookings Made by Agents.
top_ten_bookings = df1['agent'].value_counts().reset_index().rename(columns = {'index':'Agent_ID','agent':'No_of_Bookings'})[:10]
top_ten_bookings
# Out:
#    Agent_ID  No_of_Bookings
# 0       9.0           28721
# 1     240.0           13028
# 2       0.0           12141
# 3      14.0            3342
# 4       7.0            3294
# 5     250.0            2779
# 6     241.0            1644
# 7      28.0            1493
# 8       8.0            1383
# 9       1.0            1228

# %%
# Visualizsing the No of Bookings made by Agents.
fig = plt.figure(figsize = (10, 5))
sns.barplot(x=top_ten_bookings['Agent_ID'],y=top_ten_bookings['No_of_Bookings'],order=top_ten_bookings['Agent_ID'])
plt.title('Bookings Made By Agents')
# Out:
# Text(0.5, 1.0, 'Bookings Made By Agents')

# %% [markdown]
# #### **Observation :**
# The Agent ID 9 has made highest No of Bookings.

# %% [markdown]
# ## **3. What is the rate of Booking Cancellation?**

# %%
df1['is_canceled'].value_counts().plot.pie(explode =[0.05,0.05], autopct = '%.2f%%',shadow = True, figsize=(10,8),fontsize = 20)
plt.title('Pie Chart For Canceled or Not Canceled')
# Out:
# Text(0.5, 1.0, 'Pie Chart For Canceled or Not Canceled')

# %% [markdown]
# #### **Observation :**
# 0 = Bookings Which Not Canceled. <br>
# 1 = Bookings Which Canceled. <br>
# **27.52% Bookings Was Canceled.**

# %% [markdown]
# ## **4. What is the rate of guests who come frequently?**

# %%
df1['is_repeated_guest'].value_counts().plot.pie(explode=[0.1,0.1],autopct='%.2f%%',figsize=(10,8),fontsize=20,colors=['Red','Green'])
plt.title('Percentage of Repeated Guests')
# Out:
# Text(0.5, 1.0, 'Percentage of Repeated Guests')

# %% [markdown]
# #### **Observation :**
# 0 = Which are not Repeated Guests. <br>
# 1 = Which are Repeated Guests.<br>
# **The Rate of Repeated Guests is very low i.e 3.86%**

# %% [markdown]
# ## **5. What is the rate of distribution to "Customer Type"?**

# %%
df1['customer_type'].value_counts().plot.pie(explode=[0.05,0.05,0.05,0.05],autopct='%.2f%%',figsize=(10,8),fontsize=20)
plt.title('Distribution of Customer Type')
# Out:
# Text(0.5, 1.0, 'Distribution of Customer Type')

# %% [markdown]
# #### **Observation :**
# **1. Contract**
# >when the booking has an allotment or other type of contract associated to it.
#
# **2. Group**
# > when the booking is associated to a group.
#
# **3. Transient**
# >when the booking is not part of a group or contract, which is not associated to other transient booking.
#
# **4. Transient-party**
# >when the booking is transient, but it is associated to at least other transient booking.
#
# #### **The rate of booking associated by Transient is more whcih is 82.38 % and rate of  Booking associated by the Group is vey low which is 0.62%.**

# %% [markdown]
# ## **6. What is the rate of distribution of car parking spaces required?**

# %%
df1['required_car_parking_spaces'].value_counts().plot.pie(explode=[0.05]*5,autopct='%.2f%%',figsize=(10,8),fontsize=20)
labels=df1['required_car_parking_spaces'].value_counts().index
plt.title('Distribution of required car parking spaces')
# Out:
# Text(0.5, 1.0, 'Distribution of required car parking spaces')

# %%
parking_spaces_required = df1['required_car_parking_spaces'].value_counts().reset_index().rename(columns={'index':'Parking Spaces','required_car_parking_spaces':'Counts'})
sns.barplot(x=parking_spaces_required['Parking Spaces'],y=parking_spaces_required['Counts']*100/df1.shape[0])
plt.title('Distribution of required car parking spaces')
plt.xlabel('Car Parking Spaces Required')
plt.ylabel('Percentage(%)')
# Out:
# Text(0, 0.5, 'Percentage(%)')

# %% [markdown]
# #### **Observation :**
# **Only 8.3 % guests required 1 parking space rest all did not required parking spaces which is about 91.6%.**

# %% [markdown]
# ## **7. What is the rate of booking changes made by the customer.?**

# %%
change_in_bookings = df1['booking_changes'].value_counts().reset_index().rename(columns={'index': "number_booking_changes",'booking_changes':'Counts'})
sns.barplot(x=change_in_bookings['number_booking_changes'],y=change_in_bookings['Counts']*100/df1.shape[0])
plt.title('Booking Changes')
plt.xlabel('Number of booking changes')
plt.ylabel('Percentage(%)')
# Out:
# Text(0, 0.5, 'Percentage(%)')

# %% [markdown]
# #### **Observation :**
# 0= 0 changes made in the booking<br>
# 1= 1 changes made in the booking<br>
# 2= 2 changes made in the booking<br>
#
# **About 82% of the bookings were not changed by guests.**

# %% [markdown]
# ## **8. What is Percentage distribution of Deposite type ?**

# %%
df1['deposit_type'].value_counts().plot.pie(explode=[0.05,0.45,0.15],autopct='%.2f%%',figsize=(10,8),fontsize=20,labels=None)
plt.title("Distribution of deposit type")
labels=df1['deposit_type'].value_counts().index.tolist()
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# #### **Observation :**
# The Most of Guests Prefer 'No Deposit' type of deposit, the rate for it is 87.65%

# %% [markdown]
# ## **9. Which is mostly preferred type of food by the guests?**

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=df1['meal'])
plt.title('Preferred Meal Type')
plt.xlabel('Meal Type')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### **Observation :**
# Types of meal in hotels:
# * BB - (Bed and Breakfast)
# * HB- (Half Board)
# * FB- (Full Board)
# * SC- (Self Catering)
#
# #### The most preferred meal type by the guests is BB( Bed and Breakfast)
# #### HB- (Half Board) and SC- (Self Catering) are equally preferred.

# %% [markdown]
# ## **10. Which room type do clients prefer the most?**

# %%
df1['assigned_room_type'].value_counts().plot.bar(figsize=(10,8),fontsize=20)
plt.title('Most Preferred Room Type')
plt.ylabel('Count of Room Type')
plt.xlabel('Room Type')
# Out:
# Text(0.5, 0, 'Room Type')

# %% [markdown]
# #### **Observation :**
# The Most Preferred Room Type is 'A'.

# %% [markdown]
# ## **11. Which month saw the most Bookings?**

# %%
# Finding Month wise booking counts
Bookings = df1['arrival_date_month'].value_counts().reset_index().rename(columns={'index':'Months','arrival_date_month':'No of Bookings'})
# Create list of months in order
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
# creating df which will map the order of above months list without changing its values.
Bookings['Months'] = pd.Categorical(Bookings['Months'],categories=months,ordered=True)
# sorting by arrival_date_month
Bookings_by_Months = Bookings.sort_values('Months')
Bookings_by_Months
# Out:
#        Months  No of Bookings
# 11    January            4685
# 8    February            6083
# 5       March            7489
# 3       April            7900
# 2         May            8344
# 4        June            7756
# 1        July           10043
# 0      August           11242
# 7   September            6682
# 6     October            6921
# 10   November            4973
# 9    December            5112

# %%
# Set Fifuresize
plt.figure(figsize=(15,8))
# Plooting Barchart
sns.barplot(x=Bookings_by_Months['Months'],y=Bookings_by_Months['No of Bookings'])
plt.title('Month Wise Bookings')
# Out:
# Text(0.5, 1.0, 'Month Wise Bookings')

# %% [markdown]
# #### **Observation :**
# The Most Bookings Was in July And August.

# %% [markdown]
# ## **13. Which distribution channel is most preferred for hotel Bookings?**

# %%
#Creating labels
labels=df1['distribution_channel'].value_counts().index.tolist()

# creating new df of distribution channel
distribution_channel_df=df1['distribution_channel'].value_counts().reset_index().rename(columns={'index':"distribution_channel",'distribution_channel':'count'})

#adding percentage columns to the distribution_channel_df
distribution_channel_df['percentage']=round(distribution_channel_df['count']*100/df1.shape[0],1)

#Creating list of percentage
sizes=distribution_channel_df['percentage'].values.tolist()

#plotting the piw chart
df1['distribution_channel'].value_counts().plot.pie(explode=[0.05, 0.05,0.05,0.05,0.05], shadow=False, figsize=(15,8),fontsize=10,labels=None)   

# setting legends with the percentage values
labels = [f'{l}, {s}%' for l, s in zip(labels, sizes)]
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)
plt.title(' Mostly Used Distribution Channel for Hotel Bookings ')
# Out:
# Text(0.5, 1.0, ' Mostly Used Distribution Channel for Hotel Bookings ')

# %% [markdown]
# ## **Observation :**
# 'TA/TO' is mostly(79.1%) used for booking hotels.

# %% [markdown]
# ## **14. Which year had the most bookings?**

# %%
# set plot size
plt.figure(figsize=(10,8))
# plot with countplot
sns.countplot(x=df1['arrival_date_year'],hue=df1['hotel'])
plt.title("Year Wise bookings")
# Out:
# Text(0.5, 1.0, 'Year Wise bookings')

# %% [markdown]
# ### **Observation**
# ###2016 had the higest bookings.
# ###2015 had less 7000 bookings.
# ###Overall City hotels had the most of the bookings.

# %% [markdown]
# ## **15. From which country the most guests are coming?**

# %%
# Counting the guests from various countries.
country_df=df1['country'].value_counts().reset_index().rename(columns={'index': 'country','country': 'count of guests'})[:10]

# Visualizing by  plotting the graph
plt.figure(figsize=(20,8))
sns.barplot(x=country_df['country'],y=country_df['count of guests'])
plt.xlabel('Country')
plt.ylabel('Number of guests',fontsize=12)
plt.title("Number of guests from diffrent Countries")
# Out:
# Text(0.5, 1.0, 'Number of guests from diffrent Countries')

# %% [markdown]
# ## **Bivariate and Multivariate Analysis**

# %%
# Making group by Hotel Type.
group_by_hotel = df1.groupby('hotel')

# %% [markdown]
# ## **1. Which type of Hotel has the highest ADR?**

# %%
# finding the mean of ADR for both hotel type
adr_mean = group_by_hotel['adr'].mean()

# plot the bar chart
adr_mean.plot.bar(figsize=(12,8),color=['Blue','Green'])
plt.title('Average ADR of Hotel Type')
plt.ylabel('Mean ADR')
plt.xlabel('Hotel Type')
# Out:
# Text(0.5, 0, 'Hotel Type')

# %% [markdown]
# #### **Observation :**
# #### The highest ADR is at the City Hotel. This indicates that city hotels make more money than resort hotels. The revenue increases as ADR increases.

# %% [markdown]
# ## **2. Which hotel type has the more lead time?**
#
# 1.   List item
# 2.   List item

# %%
# finding the mean of lead time for both hotel type
adr_mean = group_by_hotel['lead_time'].mean()

# plot the bar chart
adr_mean.plot.bar(figsize=(12,8),color=['Green','Red'])
plt.title('Average Lead Time of Hotel Type')
plt.ylabel('Mean Lead Time')
plt.xlabel('Hotel Type')
# Out:
# Text(0.5, 0, 'Hotel Type')

# %% [markdown]
# #### **Observation :**
# #### Resort Hotels have a slightly longer average lead time. Customers must make very early travel plans as a result.

# %% [markdown]
# ## **3. Which hotel has the most rate of cancellations?**
#
# ---

# %%
# booking canceled=1 
# booking not canceled= 0

# Making a New Dataframe where bookings are canceled
canceled_df = df1[df1['is_canceled']==1]

# Calculating Canceled bookings for Each Hotel type
canceled_df = canceled_df.groupby('hotel').size().reset_index().rename(columns={0: "No_of_Cancelled_Bookings"})

# Calculating Total No of Bookings
canceled_df['total_booikngs'] = df1.groupby('hotel').size().reset_index().rename(columns={0:"total_Bookings"}).drop('hotel',axis=1)

# Plotting the barchart
plt.figure(figsize=(12,8))
sns.barplot(x=canceled_df['hotel'],y=canceled_df['No_of_Cancelled_Bookings']*100/canceled_df['total_booikngs'])
plt.title("Percentage of booking cancellation")
plt.xlabel('Hotel type')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# #### **Observation :**
# #### The City Hotel has highest rate of booking cancelation i.e 42.50%

# %% [markdown]
# ## **4. Which hotel has the longest waiting time?**

# %%
# Group by hotel and taking mean of waiting time.
waiting_time = df1.groupby('hotel')['days_in_waiting_list'].mean().reset_index()

plt.figure(figsize=(10,8))

# plot barchart
sns.barplot(x=waiting_time['hotel'],y=waiting_time['days_in_waiting_list'])
plt.xlabel('Hotel type')
plt.ylabel('waiting time')
plt.title("Waiting time for each hotel type")
# Out:
# Text(0.5, 1.0, 'Waiting time for each hotel type')

# %% [markdown]
# #### **Observation :**
# #### There is a lengthier wait time at city hotels than at resort hotels. As a result, we can conclude that city hotels are significantly busier than resort hotels.

# %% [markdown]
# ## **5. Which hotels receive the most repeated visitors?**

# %%
# repeated guest=1
# not repeated guest=0
#groupby hotel
groupby_hotel = df1[df1['is_repeated_guest']==1].groupby('hotel').size().reset_index().rename(columns={0:'number_of_repated_guests'})

#set plot size adn plot barplot
plt.figure(figsize=(10,8))
sns.barplot(x=groupby_hotel['hotel'],y=groupby_hotel['number_of_repated_guests'])
plt.xlabel('Hotel type')
plt.ylabel('count of repeated visitors')
plt.title("Most repeated visitors for each hotel")
# Out:
# Text(0.5, 1.0, 'Most repeated visitors for each hotel')

# %% [markdown]
# #### **Observation :**
# #### City Hotel has more repeated guests than the City Hotels.

# %% [markdown]
# ## **6. Which type of distribution let adr earn more money by making a larger contribution?**

# %%
# Making Dataframe by grouping distribution channel and hotel
distribution_channel = df1.groupby(['distribution_channel','hotel'])['adr'].mean().reset_index()

# Plotting a barchart
plt.figure(figsize=(14,8))
sns.barplot(data=distribution_channel,x='distribution_channel',y='adr',hue='hotel')
plt.title('ADR across the Distribution Channel')
# Out:
# Text(0.5, 1.0, 'ADR across the Distribution Channel')

# %% [markdown]
# * Corporate :- Bookings are made possible by corporate hotel booking companies.
# * GDS :- A GDS acts as a worldwide link between travellers and suppliers including hotels and other lodging establishments. It enables automated transactions and provides real-time product, price, and availability data to travel agencies and internet booking engines possible.
# * Direct :- Direct means that bookings are directly made with the respective hotels.
# * TA/TO :- It means that booings are made through  travel agents or travel operators.
# * Undefined :- Bookings are undefined.

# %% [markdown]
# #### **Observation :**
# #### In approximately similar amounts, "Direct" and "TA/TO" have boosted average daily rates for both types of hotels, namely "City Hotels" and "Resort Hotels."<br>
# #### GDS has highly contributed in adr in 'City Hotel' type.<br>
# #### GDS needs to increase Resort Hotel bookings.

# %% [markdown]
# ## **7. Which form of distribution has the highest cancellation?**

# %%
# Canceled = 1
# Not Canceled = 0
canceled_df = df1[df1['is_canceled']==1]

# Updating Dataframe by Making groupby distribution channel And hotel.
canceled_df = canceled_df.groupby(['distribution_channel','hotel']).size().reset_index().rename(columns={0:'counts'})

# Plotting a Barchart
plt.figure(figsize=(14,8))
sns.barplot(data=canceled_df,x='distribution_channel',y='counts',hue='hotel')
plt.title('Distribution Channel V/S Cancellation Counts')
plt.ylabel('Counts')
plt.xlabel('Distribution Channel')
# Out:
# Text(0.5, 0, 'Distribution Channel')

# %% [markdown]
# #### **Observation :**
# * In "TA/TO", City hotels has the highest cancellation as compared to resort hotels.
# * In "Direct" both the hotels has almost same cancellation.
# * In "Corporate", City hotels are more cancellation than Resort Hotel.

# %% [markdown]
# ## **8. Which Market Segment has the higest cancellation?**

# %%
# Canceled = 1
# Not Canceled = 0
canceled_df = df1[df1['is_canceled']==1]

# Updating Dataframe by Making groupby market_segment And hotel.
canceled_df = canceled_df.groupby(['market_segment','hotel']).size().reset_index().rename(columns={0:'counts'})

# Plotting a Barchart
plt.figure(figsize=(20,8))
sns.barplot(data=canceled_df,x='market_segment',y='counts',hue='hotel')
plt.title('Market Segment V/S Cancellation Counts')
plt.ylabel('Counts')
plt.xlabel('Market Segment')
# Out:
# Text(0.5, 0, 'Market Segment')

# %% [markdown]
# #### **Observations :**
# #### 'Online T/A' has the highest cancellation in both type of cities.
# #### Hotels must establish refundable/nonrefundable and deposit policies in order to decrease booking cancellations.

# %% [markdown]
# ## **9. Does the guests receive the same kind of room that they requested?**

# %%
# Define function for the reserved room type is same as requested.
def room_alloted(x):
  if x['reserved_room_type']!=x['assigned_room_type']:
    return 1
  else:
    return 0

# %%
# Update New Column to df1 dataframe
df1['Same_Room_Alloted'] = df1.apply(lambda x: room_alloted(x), axis = 1)

# Making dataframe by Group by is_canceled
canceled_groupby_df = df1.groupby('is_canceled')

# Creating Dataframe with percentage of same room alloted or not
per_df = pd.DataFrame(canceled_groupby_df['Same_Room_Alloted'].sum()*100/canceled_groupby_df.size()).reset_index().rename(columns={0:'Percentage'})
per_df
# Out:
#    is_canceled  Percentage
# 0            0   19.572610
# 1            1    2.565705

# %%
# ploting barchart
plt.figure(figsize=(12,8))
sns.barplot(x=per_df.index,y=per_df['Percentage'])
plt.title('Not getting the same room vs Booking cancellation')
plt.xlabel('is_canceled')
plt.ylabel('% of not getting same room as per reservation')
plt.xticks([0,1],['Not canceled','canceled'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f3e9b791a10>,
# ...
#  [Text(0, 0, 'Not canceled'), Text(0, 0, 'canceled')])

# %% [markdown]
# #### **Observation :**
# #### It is obvious that even if the customers are not given the rooms they requested while booking, there is little (2.5%) impact on cancellation of reservations.

# %% [markdown]
# ## **10. What is ADR in several market segments?**

# %%
# Making Groupby of market Segment And Hotel
groupby_df = df1.groupby(['market_segment','hotel'])['adr'].mean().reset_index()

# Plotting Barchart
plt.figure(figsize=(18,8))
sns.barplot(data=groupby_df,x='market_segment',y='adr',hue='hotel')
plt.title('ADR in Several Market Segments')
plt.xlabel('Market Segments')
plt.ylabel('ADR')
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# #### **Observation :**
# #### In both types of hotels, "Direct" and "Online TA" are making the most contributions.
# #### The aviation industry should prioritise boosting reservations for "City Hotels."

# %% [markdown]
# ## **11. What is the ideal length of stay for each kind of hotel?**

# %%
df_stay = df1.groupby(['Total_Stay','hotel']).agg('count').reset_index()
df_stay = df_stay.iloc[ : , :3]
df_stay =  df_stay.rename(columns={'is_canceled':'Number of Stays'})
df_stay
# Out:
#     Total_Stay         hotel  Number of Stays
# 0            0    City Hotel              231
# 1            0  Resort Hotel              360
# 2            1    City Hotel            10270
# 3            1  Resort Hotel             6899
# 4            2    City Hotel            10813
# ..         ...           ...              ...
# 68          46  Resort Hotel                1
# 69          48    City Hotel                1
# 70          56  Resort Hotel                2
# 71          60  Resort Hotel                1
# 72          69  Resort Hotel                1
#
# [73 rows x 3 columns]

# %%
# plotting Barchart.
plt.figure(figsize=(18,8))
sns.barplot(data=df_stay,x='Total_Stay',y='Number of Stays',hue='hotel')
plt.title('Ideal Stay Length in Both Hotel Types')
plt.xlabel('Total Stay (Days)')
plt.ylabel('Count of Stays')
# Out:
# Text(0, 0.5, 'Count of Stays')

# %% [markdown]
# #### **Observation :**
# #### Ideal stay length in Both the Hotel type is less than 7 Days.

# %% [markdown]
# ## **12. Relationship Between ADR And Total Stay**

# %%
# Making Group by ADR, Hotel And Total Stay.
grp_by = df1.groupby(['Total_Stay','adr','hotel']).agg('count').reset_index()
grp_by = grp_by.iloc[:,:3]
grp_by = grp_by[:18000]

# Plooting Line Chart
plt.figure(figsize=(15,8))
sns.lineplot(data=grp_by,x='Total_Stay',y='adr')
plt.title('Relationship Between ADR And Total Stay')
# Out:
# Text(0.5, 1.0, 'Relationship Between ADR And Total Stay')

# %% [markdown]
# #### **Observation :**
# #### As a Total Stay Increases the ADR is also Increases.

# %% [markdown]
# ## **13. Correlation of the columns**

# %%
plt.figure(figsize=(18,12))
sns.heatmap(df1.corr(),annot=True)
plt.title('Correlation of Columns')
# Out:
# Text(0.5, 1.0, 'Correlation of Columns')

# %% [markdown]
# #### **Observation :**
# #### 1) Same room alloted or not and is canceled have a negative correlation. Therefore, if the consumer does not receive the same accommodation that was reserved, it is doubtful that he will cancel his bookings. It is seen above.<br>
# #### 2) There is a positive correlation between lead time and total stay. That indicates that the lead time will increase the longer the customer stays.<br>
# #### 3) Adults, kids, and babies are all closely linked to one another. Thus, there will be an increase in the number of ADR.<br>
# #### 4) There is a high correlation between being a return customer and uncancelled bookings. Maybe returning visitors are not more likely to change their bookings.

# %% [markdown]
# ## **14. Relationship between the repeated guests and previous bookings not canceled?**

# %%
repeated_guests=df1[df1['is_repeated_guest']==1]
repeated_guests_1=df1[df1['is_repeated_guest']==0]
plt.figure(figsize=(10,8))
sns.barplot(x=df1['is_repeated_guest'],y= df1['previous_bookings_not_canceled'])
plt.xticks([0,1],['Not_repeated_guests','repeated_guests'],fontsize=15)
plt.title('Relationship Between repeated guests and previous bookings not cancelled.')
plt.show()

# %% [markdown]
# #### **Observation :**
# #### Booking cancellations are more common among non-repeat visitors.

# %% [markdown]
# #### **15. ADR relationship with Total Number of People**

# %%
plt.figure(figsize=(20,8))
df2=df1[df1['Total_No_of_Persons'] < 6]
sns.boxplot(x=df2['Total_No_of_Persons'],y=df2['adr'])
plt.title('ADR v/s Total Number of people')
# Out:
# Text(0.5, 1.0, 'ADR v/s Total Number of people')

# %% [markdown]
# #### **Observation :**
# #### The number of people with adr rises together with the population overallAs a result, the relationship between adr and the total population is proportional.

# %% [markdown]
# ## **Conclusions :**

# %% [markdown]
# #### 1. City hotels are the most popular hotel category with visitors. The busiest hotel is obviously City Hotel.<br>
# #### 2. Among all bookings, 27.5% of them were cancelled.
# #### 3. Only 3.9% of guests back to the hotels. 96.1 % of the visitors were new. Retention rate is therefore low.
# #### 4. More than 82% of the bookings had no changes made to them. About 10% of changes were single changes.
# #### 5. The majority of clients (91.6%) do not need parking places for their cars.
# #### 6. Travel agents and tour operators, or TA/TOs, accounted for 79.1% of all reservations.
# #### 7. BB (Bed & Breakfast) is the most popular kind of meal among visitors.
# #### 8. The majority of guests more than 25000 were from Portugal.
# #### 9. The majority of bookings for resort hotels and city hotels were made in 2016.
# #### 10. City hotel's average ADR is higher than that of resort hotels. These hotels in the city make more money than the resort hotels.
# #### 11. City hotels have a high cancellation rate of about 30%.
# #### 12. The resort hotel has a long average lead time.
# #### 13. City hotels have longer waiting times than resort hotels. So, hotels in cities are significantly busier than hotels in resort areas.
# #### 14. The majority of repeat visitors stay at resort hotels.
# #### 15. A maximum stay in any type of hotel is 7 days or fewer. People often remain for a week.
# #### 16. Although not receiving the exact room they had requested when making a hotel booking, almost 19% of people did not cancel their bookings. Only 2.5% of customers cancelled their bookings.
